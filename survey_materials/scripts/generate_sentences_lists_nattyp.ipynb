# %% [markdown]
# Mount drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Import packages

# %%
import pandas as pd
import csv
from collections import defaultdict

# %% [markdown]
# Read in files

# %%
survey = "nat"
nat_filler_path = "/content/drive/MyDrive/projects/2023/glass_project/5_9_23/naturalness_fillers_050923.csv"
typ_filler_path = "/content/drive/MyDrive/projects/2023/glass_project/5_9_23/typicality_fillers_050923.csv"
filler_path = nat_filler_path if survey == "nat" else typ_filler_path
df_filler = pd.read_csv(filler_path)
df_filler
# Out:
#           verb                                    sentence    zscore  order  \
# 0     arranged            The baby arranged the something. -0.228202      1
# 1        split                    The cow split the check.  0.641458      8
# 2      bounced              The player bounced the bottle.  0.866261     15
# 3      noticed           The stylist noticed the abruptly. -0.869346     16
# 4        drove          The chauffeur drove the carefully. -0.927087     26
# 5       shrunk              The washer shrunk the laundry.  1.048023     36
# 6       bumped                    The car bumped the curb.  1.062882     41
# 7      clipped               The gardener clipped the was. -1.069118     44
# 8     arranged               The time arranged the blocks.  0.149336      0
# 9    scratched                  The dog scratched the war.  0.262877      2
# 10  discovered         The someone discovered the theorem. -0.337085      3
# 11  discharged         The hospital discharged the candle.  0.524796      4
# 12   scratched             The anybody scratched the itch. -0.606203      5
# 13       found                  The bee found the nothing. -0.626021      6
# 14     mounted                  The rider mounted the pen.  0.632350      7
# 15    designed        The architect designed the anything. -0.656087      9
# 16   delivered             The mailman delivered the fire.  0.665315     10
# 17     smashed        The strawberry smashed the potatoes.  0.667628     11
# 18   butchered                The farmer butchered the it. -0.690341     12
# 19     ordered                The infant ordered the wine.  0.694017     13
# 20      shrunk                 The sad shrunk the laundry. -0.815528     14
# 21   dismissed          The criminal dismissed the worker.  0.883101     17
# 22     ordered            The diner ordered the expensive. -0.884493     18
# 23       split                The couple split the evenly. -0.887385     19
# 24     bounced              The loudly bounced the bottle. -0.890220     20
# 25    designed        The ballerina designed the building.  0.903825     21
# 26     secured                The we secured the location. -0.903619     22
# 27     secured              The guards secured the spider.  0.911914     23
# 28     smashed                  The cook smashed the them. -0.920891     24
# 29  discovered          The scientist discovered the wall.  0.924187     25
# 30   delivered                The they delivered the fire. -0.928312     27
# 31   butchered              The lawyer butchered the goat.  0.930559     28
# 32    poisoned           The assassin poisoned the lethal. -0.932587     29
# 33       drove                    The chef drove the limo.  0.962845     30
# 34     mounted                   The up mounted the horse. -0.961612     31
# 35    poisoned               The friend poisoned the king.  1.007160     32
# 36       threw                The athlete threw the while. -1.021421     33
# 37     clipped             The gardener clipped the hedge.  1.044281     34
# 38       lined               The butterfly lined the with. -1.045695     35
# 39   permitted                 The cup permitted the ever. -1.050682     37
# 40  recognized  The flashlight recognized the immediately. -1.055865     38
# 41       threw              The athlete threw the javelin.  1.060722     39
# 42     drained            The housekeeper drained the tub.  1.061324     40
# 43     slammed                 The child slammed the door.  1.064202     42
# 44      mocked                     The cat mocked the for. -1.065938     43
# 45       lined                  The tailor lined the coat.  1.081788     45
# 46     noticed            The stylist noticed the wrinkle.  1.093947     46
# 47  discharged        The hospital discharged the patient.  1.094021     47
# 48   permitted            The college permitted the event.  1.103598     48
# 49  recognized       The botanist recognized the mushroom.  1.103997     49
#
#           block
# 0   calibration
# 1   calibration
# 2   calibration
# 3   calibration
# 4   calibration
# 5   calibration
# 6   calibration
# 7   calibration
# 8    experiment
# 9    experiment
# 10   experiment
# 11   experiment
# 12   experiment
# 13   experiment
# 14   experiment
# 15   experiment
# 16   experiment
# 17   experiment
# 18   experiment
# 19   experiment
# 20   experiment
# 21   experiment
# 22   experiment
# 23   experiment
# 24   experiment
# 25   experiment
# 26   experiment
# 27   experiment
# 28   experiment
# 29   experiment
# 30   experiment
# 31   experiment
# 32   experiment
# 33   experiment
# 34   experiment
# 35   experiment
# 36   experiment
# 37   experiment
# 38   experiment
# 39   experiment
# 40   experiment
# 41   experiment
# 42   experiment
# 43   experiment
# 44   experiment
# 45   experiment
# 46   experiment
# 47   experiment
# 48   experiment
# 49   experiment

# %% [markdown]
# ### Now want to read in some "sampled" sentences (i.e., from ChatGPT) and then make some csv files for our experiment, each with ~60 target items and ~40 calibration items for a total of exactly 100.

# %%
# sampled = pd.read_csv("/content/drive/MyDrive/projects/2023/glass_project/01_19_24/llama_llamasenses_generation_top_four.csv")
sampled = pd.read_csv("/content/drive/MyDrive/projects/2023/glass_project/01_26_24/llama_propbanksenses_generation_top_four.csv")
# sampled = pd.read_csv("/content/drive/MyDrive/projects/2023/glass_project/09_15_23/stephanie_sentences_with_sense.csv")

# %% [markdown]
# Leaving out the profanity check because it deleted "lube" and "ovary".

# %%
# !pip install better_profanity

# %%
# def contains_profanity(sentence):
#   return profanity.contains_profanity(sentence)

# # Create a list to store sentences with profanity
# profanity_sentences = []

# # Iterate through the DataFrame and identify sentences with profanity
# for sentence in sampled["constructed_sent"]:
#     if contains_profanity(sentence):
#         profanity_sentences.append(sentence)

# # Print sentences with profanity
# for sentence in profanity_sentences:
#     print("Profanity found in sentence:", sentence)

# # Remove sentences with profanity from the DataFrame
# sampled = sampled[~sampled["constructed_sent"].apply(lambda x: contains_profanity(x))]

# print("Number of rows removed:", len(profanity_sentences))
# sampled

# %%
import math

num_lists = math.ceil(len(sampled) / 60)

# %%
print(num_lists)
# Out:
# 13

# %%
import numpy as np
np.random.seed(0)

sampled["list_number"] = np.random.randint(1,num_lists + 1, size=len(sampled))

# %%
sampled["list_number"].value_counts()
# Out:
# 4     82
# 9     64
# 10    62
# 6     61
# 5     61
# 1     60
# 12    60
# 3     59
# 8     56
# 2     55
# 7     54
# 13    51
# 11    51
# Name: list_number, dtype: int64

# %% [markdown]
# Want to make sure no more than 60 with a given "list number."

# %%
import random
random.seed(0)


def no_more_than_n(df, max_number):
  max_number = max_number-1
  available_numbers = set(df["list_number"].unique())
  counts_dict = defaultdict(int)
  # keys are list numbers, values are number of rows assigned to that list.
  for index, row in df.iterrows():
    list_number = row["list_number"]
    if counts_dict[list_number] >= max_number:
      if list_number in available_numbers:
        available_numbers.remove(list_number)
      if available_numbers:
        new_list_number = random.choice(list(available_numbers))
        df.at[index, "list_number"] = new_list_number # updates row.
        counts_dict[new_list_number] += 1
      elif not available_numbers:
        print("Error, all list numbers are maxed out!")
    elif counts_dict[list_number] < max_number:
      counts_dict[list_number] += 1
  return df

# %%
sampled = no_more_than_n(sampled, 60)

# %%
sampled["list_number"].value_counts()
# Out:
# 2     67
# 7     60
# 13    59
# 6     59
# 1     59
# 4     59
# 12    59
# 8     59
# 10    59
# 3     59
# 5     59
# 9     59
# 11    59
# Name: list_number, dtype: int64

# %% [markdown]
# Now want to go through and create separate lists for our experiment.  Each list should have all 40 fillers plus about 60 target items, plus a few extras to get to exactly 100 total.

# %%
sampled = sampled[["verb", "sense", "sentence", "list_number"]]
# sampled = sampled[["verb_lemma", "sense", "constructed_sent", "list_number"]]
new_columns = {'verb_lemma': 'verb', 'constructed_sent': 'sentence'}
sampled = sampled.rename(columns=new_columns)

# %%
sampled["item_type"] = "target"

# %%
# calib = calib.rename(columns = {"Verb": "verb"})
calib = df_filler
calib = calib[calib["block"] != "calibration"]

# %% [markdown]
# If there's less than 100 in a given list, we add a few "extras" until it has 100 items in it.

# %%
def create_stim_csvs(calib, sampled):
  num_lists = sampled["list_number"].max()
  filler_df = calib[["verb", "sentence", "order"]]
  filler_df["item_type"] = "filler"
  filler_df["sense"] = "n/a"
  filler_df["list_number"] = "all"
  filler_df = filler_df.sort_values("order")
  # extras["sense"] = "n/a"
  for i in range(1, num_lists+1):
    target_df_subset = sampled.loc[sampled["list_number"] == i]
    extras_needed = 89-len(target_df_subset)
    extra_fillers = filler_df.head(extras_needed)
    combined = pd.concat([target_df_subset, extra_fillers])
    combined
    combined.to_csv(str(survey) + "_" + str(i) + ".csv")
    # combined = pd.concat([filler_df, target_df_subset])
    # extras_needed = 92 - len(combined)
    # extra_fillers = extras2.head(extras_needed)
    # extra_fillers["list_number"] = "extra"
    # extra_fillers["item_type"] = "extra"
    # print(combined.shape)
    # combined = pd.concat([combined, extra_fillers])
    # combined.to_csv(str(survey) + "_" + str(i) + ".csv")

# %%
create_stim_csvs(calib, sampled)
# Out:
# <ipython-input-63-233435e95cc1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filler_df["item_type"] = "filler"
